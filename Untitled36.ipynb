53. The challenge to it at behest of the petitioner thus failed on various ground. Firstly, being a candidate she has no indefeasible right of appointment; secondly on a direction of Central Government, the Institute was under a legal obligation to scrutinise the process and reply to queries raised; thirdly a two Members Committee on a detailed inquiry found above referred deviations which could not be cured as they goes to the root of process being contrary to procedure prescribed under statute and thus entire process became illegal as well as earlier inquiries were only an eye wash; fourthly earlier process was not concluded as no appointment letter was issued thus the petitioner was not required to be heard; and, fifthly the petitioner being a candidate for the post of Registrar failed to keep her away (directly or indirectly) from selection process, no matter that she was an Acting Registrar.

54. During pendency of present writ petitions a fresh process (under challenge also) of appointment of Registrar is reached to its near conclusion and petitioner on her on will has not participated in it, therefore at this belated stage Court cannot pass an order to allow her to participate in present process, however the Institute will have liberty to allow petitioner.

55. The challenge to fresh recruitment process has no basis since this Court is of considered opinion that there is no ground to interfere with a decision to declare earlier process being void.

56. The outcome of above discussion is that both writ petitions fail and are accordingly dismissed.

Order Date :-24.05.2024 AK
"""

# %%
print(len(scase))
import torch
from transformers import AutoTokenizer, AutoModel
import math
import torch.nn.functional as F
import json # Import json for formatting the API cll example
import requests

# --- Configuration ---
MODEL_NAME = "law-ai/InLegalBERT"
CHUNK_OVERLAP = 100
BATCH_SIZE = 8
TOP_K_RESULTS = 3  # How many relevant chunks to show
# ---------------------

def get_chunk_embeddings(text: str, tokenizer, model, device):
    """
    Generates embeddings for each chunk of a large text document.

    Returns:
    - all_chunk_embeddings: A tensor containing the [CLS] embedding for each chunk.
    - chunk_texts: A list of the raw text strings for each chunk.
    """
    print(f"Starting chunk embedding generation for a document with {len(text)} characters.")

    # 1. Tokenize the entire text with chunking
    max_length = tokenizer.model_max_length
    print(f"Tokenizing and chunking the text with max_length={max_length} and overlap={CHUNK_OVERLAP}...")

    # We use `return_offsets_mapping=True` to map tokens back to the original text.
    encoded_input = tokenizer(
        text,
        max_length=max_length,
        truncation=True,
        return_overflowing_tokens=True,
        stride=CHUNK_OVERLAP,
        padding="max_length",
        return_tensors="pt",
        return_offsets_mapping=True
    )

    input_ids = encoded_input['input_ids']
    attention_mask = encoded_input['attention_mask']
    offset_mapping = encoded_input['offset_mapping']

    num_chunks = input_ids.shape[0]
    print(f"Text was split into {num_chunks} overlapping chunks.")

    # Store the raw text for each chunk
    chunk_texts = []
    for i in range(num_chunks):
        # Find the end of the non-padding part of the chunk
        # `offset_mapping` gives (start_char, end_char) for each token
        # The first token [CLS] has (0, 0)
        # We find the last token *before* padding starts
        last_non_padding_index = (attention_mask[i] == 1).sum() - 1

        # Get the end character position from the offset mapping
        # [CLS] is at index 0. First *real* token is at index 1.
        first_real_token_index = 1

        # Last *real* token is one before the [SEP] token (which is at last_non_padding_index)
        last_real_token_index = last_non_padding_index - 1

        # Ensure we have a valid range of real tokens
        if last_real_token_index >= first_real_token_index:
            # Get start char from the first real token
            start_char = offset_mapping[i][first_real_token_index][0].item()

            # Get end char from the last real token
            end_char = offset_mapping[i][last_real_token_index][1].item()

            # Append the actual text
            chunk_texts.append(text[start_char:end_char])
        else:
            # This chunk is empty or only contains special tokens, append empty string
            chunk_texts.append("")

    # 3. Process chunks in batches
    all_cls_embeddings = []
    num_batches = math.ceil(num_chunks / BATCH_SIZE)

    print(f"Processing {num_chunks} chunks in {num_batches} batches of size {BATCH_SIZE}...")

    for i in range(num_batches):
        start_index = i * BATCH_SIZE
        end_index = min((i + 1) * BATCH_SIZE, num_chunks)

        batch_input_ids = input_ids[start_index:end_index].to(device)
        batch_attention_mask = attention_mask[start_index:end_index].to(device)

        with torch.no_grad():
            output = model(
                input_ids=batch_input_ids,
                attention_mask=batch_attention_mask
            )

        cls_embeddings = output.last_hidden_state[:, 0, :]
        all_cls_embeddings.append(cls_embeddings.cpu())

        if (i+1) % 10 == 0 or i+1 == num_batches:
            print(f"  ...Processed batch {i+1}/{num_batches}")

    all_chunk_embeddings = torch.cat(all_cls_embeddings, dim=0)

    print(f"Generated {all_chunk_embeddings.shape[0]} chunk embeddings.")

    return all_chunk_embeddings, chunk_texts

def get_query_embedding(query: str, tokenizer, model, device):
    """Generates a single [CLS] embedding for a query string."""
    print(f"Embedding query: '{query}'")
    encoded_input = tokenizer(
        query,
        max_length=tokenizer.model_max_length,
        truncation=True,
        padding="max_length",
        return_tensors="pt"
    )

    input_ids = encoded_input['input_ids'].to(device)
    attention_mask = encoded_input['attention_mask'].to(device)

    with torch.no_grad():
        output = model(input_ids=input_ids, attention_mask=attention_mask)

    query_embedding = output.last_hidden_state[:, 0, :]
    return query_embedding.cpu()

def find_most_similar(query_embedding, chunk_embeddings, chunk_texts, top_k):
    """
    Finds the top_k most similar chunks to the query.
    """

    # Calculate cosine similarity
    # query_embedding shape: (1, 768)
    # chunk_embeddings shape: (num_chunks, 768)
    similarities = F.cosine_similarity(query_embedding, chunk_embeddings, dim=1)

    # Get the top_k scores and their indices
    top_k_scores, top_k_indices = torch.topk(similarities, k=top_k)

    results = []
    for i in range(top_k):
        index = top_k_indices[i].item()
        score = top_k_scores[i].item()
        text = chunk_texts[index]
        results.append({"score": score, "text": text, "chunk_index": index})
    # print(results)
    return results

def prepare_llm_call(query: str, results: list):
    """
    Prepares prompts and performs an actual call to the Gemini API.
    GEMINI_API_KEY must be set in the environment. The key is redacted in logs.
    """
    print("\n" + "="*50)
    print("  STEP 3: GENERATE ANSWER WITH LLM (GEMINI)  ")
    print("="*50)

    context = "\n\n---\n\n".join([res['text'] for res in results])
    print(context)
    system_prompt_text = (
        "You are a helpful legal assistant. Based on the context I provide, "
        "answer the user's question concisely.  "

    )

    user_prompt_text = f"""
**Context:**
{context}

**Question:**
{query}
"""
    print("--- Prompts Ready for API ---")
    # Do not print the API key (redacted)
    api_key = "AIzaSyAZK12mvMhMrOoDQytcwU3DfTjxAYLtENI"
    if not api_key:
        raise RuntimeError("GEMINI_API_KEY environment variable not set. Export it and re-run the script.")
    print("Using GEMINI_API_KEY: REDACTED")

    payload = {
        "contents": [{"parts": [{"text": user_prompt_text}]}],
        "systemInstruction": {"parts": [{"text": system_prompt_text}]},
    }
    print(payload)
    model_name = "gemini-2.5-flash-preview-09-2025"
    api_url = f"https://generativelanguage.googleapis.com/v1beta/models/{model_name}:generateContent?key={api_key}"
    headers = {"Content-Type": "application/json"}

    print("--- Calling Gemini API ---")
    resp = requests.post(api_url, headers=headers, json=payload, timeout=60)

    try:
        resp.raise_for_status()
    except Exception:
        print("Gemini API request failed:", resp.status_code)
        print(resp.text)
        raise

    result = resp.json()

    # Try common response shapes to extract the generated text
    answer = None
    try:
        answer = result['candidates'][0]['content']['parts'][0]['text']
    except Exception:
        try:
            answer = result.get('output', {}).get('candidates', [])[0]['content']['parts'][0]['text']
        except Exception:
            answer = None

    if answer:
        print("--- Gemini Answer ---")
        print(answer)
    else:
        print("Unrecognized Gemini response structure; printing JSON:")
        print(json.dumps(result, indent=2))


# --- Main execution ---
if __name__ == "__main__":

    # 1. Load Model and Tokenizer
    print(f"Loading tokenizer: {MODEL_NAME}")
    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

    print(f"Loading model: {MODEL_NAME}")
    model = AutoModel.from_pretrained(MODEL_NAME)

    # 2. Set up device
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    model.to(device)
    model.eval()

    # 3. Create dummy text with a clear "answer" hidden inside


    # This is the "answer" we want our query to find

    # 4. Generate chunk embeddings for the entire document
    try:
        print("\n" + "="*50)
        print("  STEP 1: CHUNK AND EMBED DOCUMENT  ")
        print("="*50)
        chunk_embeddings, chunk_texts = get_chunk_embeddings(
            scase, tokenizer, model, device
        )

        # 5. Define a query
        query = "Who won the case?"

        # 6. Generate embedding for the query
        print("\n" + "="*50)
        print("  STEP 2: RETRIEVE RELEVANT CHUNKS  ")
        print("="*50)
        query_embedding = get_query_embedding(query, tokenizer, model, device)

        # 7. Find and display the most relevant chunks
        results = find_most_similar(
            query_embedding, chunk_embeddings, chunk_texts, TOP_K_RESULTS
        )

        print("\n--- Query ---")
        print(f"'{query}'")
        print("\n--- Top Relevant Chunks Found ---")

        for i, res in enumerate(results):
            print(f"\n--- Result {i+1} (Score: {res['score']:.4f}, Chunk: {res['chunk_index']}) ---")
            print(res['text'])
            print("-" * 40)

        # 8. NEW STEP: Prepare the LLM call
        prepare_llm_call(query, results)

    except Exception as e:
        print(f"\nAn error occurred: {e}")
        if "out of memory" in str(e).lower():
            print(">>> HINT: Try reducing the BATCH_SIZE at the top of the script.")
# Out:
# 99001
# Loading tokenizer: law-ai/InLegalBERT
# Loading model: law-ai/InLegalBERT
# Using device: cuda
#
# ...
#   STEP 1: CHUNK AND EMBED DOCUMENT
# ...
# Starting chunk embedding generation for a document with 99001 characters.
# Tokenizing and chunking the text with max_length=512 and overlap=100...
# Text was split into 52 overlapping chunks.
# Processing 52 chunks in 7 batches of size 8...
#   ...Processed batch 7/7
# Generated 52 chunk embeddings.
#
# ...
#   STEP 2: RETRIEVE RELEVANT CHUNKS
# ...
# Embedding query: 'Who won the case?'
#
# --- Query ---
# 'Who won the case?'
#
# --- Top Relevant Chunks Found ---
#
# --- Result 1 (Score: 0.4408, Chunk: 28) ---
# and non-teaching positions is also enclosed for your reference. The same procedure, was also followed earlier when the position was advertised."
#
# ...
